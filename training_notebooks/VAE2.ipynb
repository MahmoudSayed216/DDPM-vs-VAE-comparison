# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/Conditional-Variational-Auto-Encoder
# !git clone https://github.com/MahmoudSayed216/Conditional-Variational-Auto-Encoder.git
# !pip install torchmetrics[image]
# Out:
# /kaggle/working
# Cloning into 'Conditional-Variational-Auto-Encoder'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 42 (delta 23), reused 30 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 16.26 KiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# %cd "/kaggle/working/Conditional-Variational-Auto-Encoder"
# %mkdir "checkpoints"
# %cp "/kaggle/input/models/marwansayed2000/vae/pytorch/default/1/vae_epoch_050.pt" "/kaggle/working/Conditional-Variational-Auto-Encoder/checkpoints"
# %cd /kaggle/working/
# Out:
# /kaggle/working/Conditional-Variational-Auto-Encoder
# /kaggle/working

# %%
# %cd "/kaggle/working/Conditional-Variational-Auto-Encoder"
print("Started Training")
# !python3 train.py
# Out:
# /kaggle/working/Conditional-Variational-Auto-Encoder
# Started Training
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:02<00:00, 229MB/s]
# Model parameters: 29,606,179 total | 29,606,179 trainable
# Resumed from checkpoint ./checkpoints/vae_epoch_050.pt (epoch 50) -> continuing at epoch 51
# One Training
# == Epoch 51/70 done | phase=recon+kl+perceptual+adversarial | avg_recon=0.0683 avg_kl=33.6315 avg_perceptual=0.4345 avg_adv=0.9003 | time=19.04 min ==
# Saved fixed-latent sample grid -> ./samples/epoch_051.png
# == Epoch 52/70 done | phase=recon+kl+perceptual+adversarial | avg_recon=0.0692 avg_kl=33.8610 avg_perceptual=0.4433 avg_adv=0.9057 | time=19.18 min ==
# Saved fixed-latent sample grid -> ./samples/epoch_052.png
# ...
