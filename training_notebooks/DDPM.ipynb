# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/Denoising-Diffusion-Probabilistic-Models-DDPM-
# !git clone https://github.com/MahmoudSayed216/Denoising-Diffusion-Probabilistic-Models-DDPM-.git
# !pip install torchmetrics[image]
# Out:
# /kaggle/working
# Cloning into 'Denoising-Diffusion-Probabilistic-Models-DDPM-'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 102 (delta 49), reused 75 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 537.55 KiB | 4.41 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# %cd "/kaggle/working/Denoising-Diffusion-Probabilistic-Models-DDPM-"
# !python3 train.py
# Out:
# /kaggle/working/Denoising-Diffusion-Probabilistic-Models-DDPM-
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:02<00:00, 187MB/s]
# == Epoch 1/70 done | phase=recon | avg_recon=0.0792 avg_perceptual=0.0000 avg_adv=0.0000 ==
# Saved fixed-noise sample grid -> ./samples/epoch_001.png
# == Epoch 2/70 done | phase=recon | avg_recon=0.0510 avg_perceptual=0.0000 avg_adv=0.0000 ==
# Saved fixed-noise sample grid -> ./samples/epoch_002.png
# == Epoch 3/70 done | phase=recon | avg_recon=0.0490 avg_perceptual=0.0000 avg_adv=0.0000 ==
# Saved fixed-noise sample grid -> ./samples/epoch_003.png
# == Epoch 4/70 done | phase=recon | avg_recon=0.0490 avg_perceptual=0.0000 avg_adv=0.0000 ==
# Saved fixed-noise sample grid -> ./samples/epoch_004.png
# ...
